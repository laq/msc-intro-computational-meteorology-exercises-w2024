# %% [markdown]
# * With the current setup
#     * Get the yearly mean for our rough estimate
#
#     * Get the weighted areas, to get energy per grid box
#
#
#
#
# * Can we satisfy the instantaneus demand?
#     * Get the instantaneus max demand in a year (Najme)
#
# * Where to put the solar panels?
#    * Which are the areas of higher contribution (Selma's cool algorithm)
#        * Use top 30 boxes for the local maxima ie, 30 boxes with highest pvpot (mean pvpot or sum pvpot)
#    * What makes a place a good place to put solar panels? (Najme)
#        *  Radiation, temperature and wind are already accounted in pvpot
#        *  ?
#        *  Are mountains a good place?
#        *  Populated areas?
#        *  Beach front
#        *  Natural reserves (parks)
#        *  Ocean or sea ? can we put them in the mediterranian
#
# * Problem for the future:
#     * Max pvpot is at mid day, max consumption is in the evenening
#        * What is the maximum difference?
#        * How much energy should be stored or commerced(import export)?

# %%
# %load_ext autoreload
# %autoreload
import tools as tools
import core as core

# %%
# Open dataset and filter for europe
# range=> [) is open on the right side so +1 to remember
ds = tools.open_dataset(months=range(1,12+1))
ds_eu = tools.filter_europe_box(ds)

# Filter for Iran
# ds_eu = ds.sel(latitude=slice(40, 24)).sel(longitude=slice(40, 62))

# %%
ds_eu
# Out:
# <xarray.Dataset> Size: 405MB
# Dimensions:     (valid_time: 744, latitude: 141, longitude: 161)
# Coordinates:
#     number      int64 8B ...
#   * valid_time  (valid_time) datetime64[ns] 6kB 2000-01-01 ... 2000-01-31T23:...
#   * latitude    (latitude) float64 1kB 70.0 69.75 69.5 69.25 ... 35.5 35.25 35.0
#   * longitude   (longitude) float64 1kB -10.0 -9.75 -9.5 ... 29.5 29.75 30.0
#     expver      (valid_time) <U4 12kB dask.array<chunksize=(744,), meta=np.ndarray>
# Data variables:
#     t2m         (valid_time, latitude, longitude) float32 68MB dask.array<chunksize=(744, 41, 40), meta=np.ndarray>
#     ssrd        (valid_time, latitude, longitude) float32 68MB dask.array<chunksize=(744, 41, 40), meta=np.ndarray>
#     ssrdc       (valid_time, latitude, longitude) float32 68MB dask.array<chunksize=(744, 41, 40), meta=np.ndarray>
#     u10         (valid_time, latitude, longitude) float32 68MB dask.array<chunksize=(744, 41, 40), meta=np.ndarray>
#     v10         (valid_time, latitude, longitude) float32 68MB dask.array<chunksize=(744, 41, 40), meta=np.ndarray>
#     wspd        (valid_time, latitude, longitude) float32 68MB dask.array<chunksize=(744, 41, 40), meta=np.ndarray>
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2024-10-21T19:50 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
# Lets do a rough estimate calculating the overall mean
pvpot_pre = core.pv_pot(ds_eu).groupby(ds_eu.valid_time.dt.month).mean(dim=("valid_time","latitude","longitude"))

# %%
# Do the proper computation
pvpot = tools.dask_compute(pvpot_pre, workers=5, threads=2)
# Out:
# <Client: 'tcp://127.0.0.1:33859' processes=5 threads=10, memory=753.83 GiB>
# Execution time: 25.45687 seconds

# %%
pvpot.values
# Out:
# array([0.04707821, 0.07786103, 0.13314854, 0.18694378, 0.23292613,
#        0.24583708, 0.22280404, 0.19147107, 0.13748726, 0.08209264,
#        0.04819918, 0.03547181], dtype=float32)

# %%
print(f"Each square meter can produce a max of {pvpot.values*237} Watts in January")
# Out:
# Each square meter can produce a max of [11.157536] Watts in January

# %%
import pint
from pint import UnitRegistry
ureg = UnitRegistry()

# Doing a naive calculation of europe

#AREA:
area_europe = 10.53e6 * (ureg.kilometer * ureg.kilometer)
# '#' compact '~' short 'P' Pretty
print(f"Area Europe: {area_europe:#P}")

# Panel rate for panels ---
panel_rated_ouput = 237 * ureg.watt / (ureg.meter * ureg.meter)
print(f"Panel Rated Output: {panel_rated_ouput:#~P}")

europe_max_solar_energy = pvpot.values.item() * panel_rated_ouput * area_europe
print(f"Max solar energy production europe: {europe_max_solar_energy:#~P.2f}")


europe_max_solar_energy_month = europe_max_solar_energy * (720 * ureg.hour)
print(f"Max solar energy production europe month Wh: {europe_max_solar_energy_month:#~P.2f}")
print(f"Max solar energy production europe month J: {europe_max_solar_energy_month.to('joule'):#P.2f}")
# Out:
# Area Europe: 10.53 megameter²
# Panel Rated Output: 237.0 W/m²
# Max solar energy production europe: 117.49 TW
# Max solar energy production europe month Wh: 84.59 PW·h
# Max solar energy production europe month J: 304.53 exajoule

# %%
area_europe
# Out:
# 10530000.0 <Unit('kilometer ** 2')>

# %%
# https://ec.europa.eu/eurostat/databrowser/view/nrg_cb_e__custom_13932565/default/table?lang=en
europe_electricity_consumption = 2824313.722 * 10e9 * ureg.Wh
print(f"{europe_electricity_consumption.to('gigawatthour'):_}")
print(f"{europe_electricity_consumption.to('gigawatthour'):#~P}")
# Out:
# 28_243_137.220000003 gigawatt_hour
# 28.24313722 PWh

# %%
 europe_electricity_consumption / europe_max_solar_energy_month
# Out:
# 333874.9013344226 <Unit('meter ** 2 * watt_hour / hour / kilometer ** 2 / watt')>

# %%
84.59/28.2
# Out:
# 2.9996453900709223

# %%
(28.2/12)/84.59
# Out:
# 0.027781061591204633

# %%
area_europe_km2 = 10.53e6 # * ureg.meter * ureg.meter # km2
area_europe_m2 = area_europe_km2 * 1e6

# Panel rate for panels ---
panel_rated_ouput_per_m2 = 237

europe_watts_per_m2 = pvpot * panel_rated_ouput_per_m2
europe_watts = europe_watts_per_m2 * area_europe_m2
# europe_watts_hour = europe_watts * 3600

# %%
europe_watts_computed = europe_watts.compute()
europe_watts_val = europe_watts_computed.values.item()
# Out:
# /headless/envs/magic/lib/python3.10/site-packages/xarray/core/variable.py:306: UnitStrippedWarning: The unit of the quantity is stripped when downcasting to ndarray.
#   data = np.asarray(data)

# %%
print(f"Europe can produce {europe_watts_val:.3e} W")
# Out:
# Europe can produce 1.175e+14 W

# %%
print(f"Europe can produce {europe_watts_val/1e12:.3f} TW")
# Out:
# Europe can produce 117.489 TW

# %%
# To get the number of jules multiply by the seconds in a month
europe_joules_month = europe_watts_val * 3600 * 24 * 30

# %%
print(f"Europe can produce {europe_joules_month:.3e} Jules in a month")
# Out:
# Europe can produce 3.045e+20 Jules in a month

# %%
print(f"Europe could have produced {europe_joules_month/1e18:.3f} Exa Jules",
      "in the month of January of 2000 if was fully covered with solar panels")
# Out:
# Europe could have produced 304.531 Exa Jules in the month of January of 2000 if was fully covered with solar panels

# %%
import pint

# %%
# Main pvpot calculation and grouping
pvpot_pre = core.pv_pot(ds_eu).groupby(ds_eu.valid_time.dt.month).sum("valid_time")
# Overal mean

# %%
# Multiplying by rateHeat
panel_rated_ouput_per_m2 = 237
# Rate times 3600 to have watts to watts hour, divide over 1e6 to get mega watts hour
energy_month = pvpot_pre * panel_rated_ouput_per_m2 * 3600 / 1_000_000

# For area per box 
# a b = pi a dlat/180 dlat:1/4
# dx = 2 pi a dlon/360  cos theta
# Area = dy dx const const cos(theta)

# %%
# Do the proper computation
pvpot = tools.dask_compute(energy_month)
# Out:
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7efc8c5838e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7fcce17d78e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7f4fdeb078e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# 2024-11-25 20:37:14,394 - distributed.nanny - ERROR - Worker process died unexpectedly
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7f79b4b1f8e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
# Process Dask Worker process (from Nanny):
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Process Dask Worker process (from Nanny):
# 2024-11-25 20:37:14,491 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# 2024-11-25 20:37:14,492 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# 2024-11-25 20:37:14,493 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2024-11-25 20:37:14,491 - distributed.nanny - ERROR - Worker process died unexpectedly
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process Dask Worker process (from Nanny):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
# Process Dask Worker process (from Nanny):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/process.py", line 188, in _run
#     target(*args, **kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 941, in _run
#     loop.run_sync(do_stop)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in run_sync
#     raise TimeoutError("Operation timed out after %s seconds" % timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
# tornado.util.TimeoutError: Operation timed out after None seconds
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 152, in <module>
#     from pandas.core import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexing.py", line 79, in <module>
#     from pandas.core.indexes.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/api.py", line 28, in <module>
#     from pandas.core.indexes.datetimes import DatetimeIndex
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py", line 47, in <module>
#     from pandas.core.indexes.datetimelike import DatetimeTimedeltaMixin
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/datetimelike.py", line 69, in <module>
#     from pandas.core.indexes.range import RangeIndex
# KeyboardInterrupt
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#
# During handling of the above exception, another exception occurred:
#
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/process.py", line 188, in _run
#     target(*args, **kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 941, in _run
#     loop.run_sync(do_stop)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in run_sync
#     raise TimeoutError("Operation timed out after %s seconds" % timeout)
# tornado.util.TimeoutError: Operation timed out after None seconds
# 2024-11-25 20:37:14,592 - distributed.nanny - ERROR - Worker process died unexpectedly
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 152, in <module>
#     from pandas.core import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexing.py", line 79, in <module>
#     from pandas.core.indexes.api import (
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
# KeyboardInterrupt
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#
# During handling of the above exception, another exception occurred:
#
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/process.py", line 188, in _run
#     target(*args, **kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 941, in _run
#     loop.run_sync(do_stop)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in run_sync
#     raise TimeoutError("Operation timed out after %s seconds" % timeout)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 152, in <module>
#     from pandas.core import (
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexing.py", line 79, in <module>
#     from pandas.core.indexes.api import (
# tornado.util.TimeoutError: Operation timed out after None seconds
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/api.py", line 20, in <module>
#     from pandas.core.indexes.base import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 190, in <module>
#     from pandas.core.strings.accessor import StringMethods
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/process.py", line 188, in _run
#     target(*args, **kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 941, in _run
#     loop.run_sync(do_stop)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in run_sync
#     raise TimeoutError("Operation timed out after %s seconds" % timeout)
# tornado.util.TimeoutError: Operation timed out after None seconds
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 152, in <module>
#     from pandas.core import (
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
# KeyboardInterrupt
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#
# During handling of the above exception, another exception occurred:
#
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/process.py", line 188, in _run
#     target(*args, **kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 184, in <module>
#     from pandas.core.methods.describe import describe_ndframe
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 941, in _run
#     loop.run_sync(do_stop)
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/methods/describe.py", line 41, in <module>
#     from pandas.io.formats.format import format_percentiles
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in run_sync
#     raise TimeoutError("Operation timed out after %s seconds" % timeout)
# tornado.util.TimeoutError: Operation timed out after None seconds
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/process.py", line 188, in _run
#     target(*args, **kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 941, in _run
#     loop.run_sync(do_stop)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in run_sync
#     raise TimeoutError("Operation timed out after %s seconds" % timeout)
# tornado.util.TimeoutError: Operation timed out after None seconds
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 184, in <module>
#     from pandas.core.methods.describe import describe_ndframe
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/methods/describe.py", line 41, in <module>
#     from pandas.io.formats.format import format_percentiles
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/process.py", line 188, in _run
#     target(*args, **kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 941, in _run
#     loop.run_sync(do_stop)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in run_sync
#     raise TimeoutError("Operation timed out after %s seconds" % timeout)
# tornado.util.TimeoutError: Operation timed out after None seconds
# 2024-11-25 20:37:14,893 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 152, in <module>
#     from pandas.core import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexing.py", line 79, in <module>
#     from pandas.core.indexes.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/api.py", line 28, in <module>
#     from pandas.core.indexes.datetimes import DatetimeIndex
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py", line 47, in <module>
#     from pandas.core.indexes.datetimelike import DatetimeTimedeltaMixin
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/process.py", line 188, in _run
#     target(*args, **kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 941, in _run
#     loop.run_sync(do_stop)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in run_sync
#     raise TimeoutError("Operation timed out after %s seconds" % timeout)
# tornado.util.TimeoutError: Operation timed out after None seconds
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7f202f5638e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Exception ignored in: Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7f4f7b3b78e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
# <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7f076852f8e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7f5ef71838e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# 2024-11-25 20:37:15,891 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 19, in <module>
#     from pandas.core.arrays.sparse import SparseArray
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/arrays/sparse/__init__.py", line 1, in <module>
#     from pandas.core.arrays.sparse.accessor import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/arrays/sparse/accessor.py", line 17, in <module>
#     from pandas.core.arrays.sparse.array import SparseArray
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/headless/envs/magic/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/process.py", line 188, in _run
#     target(*args, **kwargs)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 941, in _run
#     loop.run_sync(do_stop)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 529, in run_sync
#     raise TimeoutError("Operation timed out after %s seconds" % timeout)
# tornado.util.TimeoutError: Operation timed out after None seconds
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7f35145978e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7f9896c2b8e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Task exception was never retrieved
# future: <Task finished name='Task-1' coro=<WorkerProcess._run.<locals>.run() done, defined at /headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py:887> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 184, in <module>
#     from pandas.core.methods.describe import describe_ndframe
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/methods/describe.py", line 41, in <module>
#     from pandas.io.formats.format import format_percentiles
# KeyboardInterrupt
# Task exception was never retrieved
# future: <Task finished name='Task-1' coro=<WorkerProcess._run.<locals>.run() done, defined at /headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py:887> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
# ...
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 152, in <module>
#     from pandas.core import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexing.py", line 79, in <module>
#     from pandas.core.indexes.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/api.py", line 20, in <module>
#     from pandas.core.indexes.base import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/base.py", line 190, in <module>
#     from pandas.core.strings.accessor import StringMethods
# KeyboardInterrupt
# Task exception was never retrieved
# future: <Task finished name='Task-1' coro=<WorkerProcess._run.<locals>.run() done, defined at /headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py:887> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
# KeyboardInterrupt
# Exception ignored in: <bound method GCDiagnosis._gc_callback of <distributed.utils_perf.GCDiagnosis object at 0x7fcda1acb8e0>>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/utils_perf.py", line 179, in _gc_callback
#     def _gc_callback(self, phase, info):
# KeyboardInterrupt:
# Task exception was never retrieved
# future: <Task finished name='Task-1' coro=<WorkerProcess._run.<locals>.run() done, defined at /headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py:887> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 28, in <module>
#     from pandas.core.arrays import Categorical
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/arrays/__init__.py", line 19, in <module>
#     from pandas.core.arrays.sparse import SparseArray
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/arrays/sparse/__init__.py", line 1, in <module>
#     from pandas.core.arrays.sparse.accessor import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/arrays/sparse/accessor.py", line 17, in <module>
#     from pandas.core.arrays.sparse.array import SparseArray
# KeyboardInterrupt
# 2024-11-25 20:37:22,494 - distributed.nanny - WARNING - Restarting worker
# Task exception was never retrieved
# future: <Task finished name='Task-1' coro=<WorkerProcess._run.<locals>.run() done, defined at /headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py:887> exception=KeyboardInterrupt()>
# Traceback (most recent call last):
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 934, in _run
#     loop.run_sync(run)
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/ioloop.py", line 524, in run_sync
#     self.start()
#   File "/headless/envs/magic/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 199, in start
#     self.asyncio_loop.run_forever()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 600, in run_forever
#     self._run_once()
#   File "/headless/envs/magic/lib/python3.10/asyncio/base_events.py", line 1896, in _run_once
#     handle._run()
#   File "/headless/envs/magic/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *s2024-11-25 20:37:23,494 - distributed.nanny - WARNING - Restarting worker
# elf._args)
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/nanny.py", line 892, in run
#     await worker
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/core.py", line 481, in start
#     await asyncio.wait_for(self.start_unsafe(), timeout=timeout)
#   File "/headless/envs/magic/lib/python3.10/asyncio/tasks.py", line 408, in wait_for
#     return await fut
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1408, in start_unsafe
#     await self._register_with_scheduler()
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/worker.py", line 1100, in _register_with_scheduler
#     versions=get_versions(),
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 50, in get_versions
#     "packages": get_package_info(
#   File "/headless/envs/magic/lib/python3.10/site-packages/distributed/versions.py", line 100, in get_package_info
#     mod = importlib.import_module(modname)
#   File "/headless/envs/magic/lib/python3.10/importlib/__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "<frozen importlib._bootstrap>", line 1050, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1027, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1006, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 688, in _load_unlocked
#   File "<frozen importlib._bootstrap_external>", line 883, in exec_module
#   File "<frozen importlib._bootstrap>", line 241, in _call_with_frames_removed
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/__init__.py", line 49, in <module>
#     from pandas.core.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/api.py", line 47, in <module>
#     from pandas.core.groupby import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/__init__.py", line 1, in <module>
#     from pandas.core.groupby.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/groupby/generic.py", line 68, in <module>
#     from pandas.core.frame import DataFrame
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/frame.py", line 149, in <module>
#     from pandas.core.generic import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/generic.py", line 152, in <module>
#     from pandas.core import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexing.py", line 79, in <module>
#     from pandas.core.indexes.api import (
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/api.py", line 28, in <module>
#     from pandas.core.indexes.datetimes import DatetimeIndex
#   File "/headless/envs/magic/lib/python3.10/site-packages/pandas/core/indexes/datetimes.py", line 47, in <module>
#     from pandas.core.indexes.datetimelike import DatetimeTimedeltaMixin
# KeyboardInterrupt
# 2024-11-25 20:37:24,192 - distributed.nanny - WARNING - Restarting worker
# 2024-11-25 20:37:28,494 - distributed.nanny - WARNING - Restarting worker
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Do the proper computation
# ----> 2 pvpot = tools.dask_compute(energy_month)
#
# File ~/exe1/msc-intro-computational-meteorology-exercises-w2024/projects/europeEnergy/tools.py:24, in dask_compute(xarray, workers, threads)
#      22 dask_workspace = home / "daskWorkspace"
#      23 # Using Dask Client as a context manager
# ---> 24 with Client(n_workers=workers, threads_per_worker=threads, local_directory=dask_workspace) as client:
#      25     print(client)
#      26     start_time = time.time()
#
# File /headless/envs/magic/lib/python3.10/site-packages/distributed/client.py:943, in Client.__init__(self, address, loop, timeout, set_as_default, scheduler_file, security, asynchronous, name, heartbeat_interval, serializers, deserializers, extensions, direct_to_workers, connection_limit, **kwargs)
#     940 preload_argv = dask.config.get("distributed.client.preload-argv")
#     941 self.preloads = preloading.process_preloads(self, preload, preload_argv)
# --> 943 self.start(timeout=timeout)
#     944 Client._instances.add(self)
#     946 from distributed.recreate_tasks import ReplayTaskClient
#
# File /headless/envs/magic/lib/python3.10/site-packages/distributed/client.py:1133, in Client.start(self, **kwargs)
#    1131     self._started = asyncio.ensure_future(self._start(**kwargs))
#    1132 else:
# -> 1133     sync(self.loop, self._start, **kwargs)
#
# File /headless/envs/magic/lib/python3.10/site-packages/distributed/utils.py:401, in sync(loop, func, callback_timeout, *args, **kwargs)
#     399 else:
#     400     while not e.is_set():
# --> 401         wait(10)
#     403 if error:
#     404     typ, exc, tb = error
#
# File /headless/envs/magic/lib/python3.10/site-packages/distributed/utils.py:390, in sync.<locals>.wait(timeout)
#     388 def wait(timeout):
#     389     try:
# --> 390         return e.wait(timeout)
#     391     except KeyboardInterrupt:
#     392         loop.add_callback(cancel)
#
# File /headless/envs/magic/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File /headless/envs/magic/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
tools.print_pvpot_stats(pvpot)
# Out:
# Calculated pvpot:
#     Shape: (12, 141, 161)
#     Months: 12
#     Min: 0.0
#     Mean: 85.50216139585734
#     Max: 200.433008
#     Std: 53.33090058174218

# %%
import matplotlib.pyplot as plt

# %%
fg, ax = tools.plot_pvpot_per_month(pvpot, 0, pvpot.max())
fg.suptitle("MegaWatts Hour per month per m^2")
# Out:
# Text(0.5, 0.98, 'MegaWatts Hour per month per m^2')
